# %%
ieee_paths
# Out:
# {'ieee_29573': ['Computational and artificial intelligence',
#   'Neural networks',
#   'Multi-layer neural network'],
#  'ieee_4035': ['Computational and artificial intelligence',
#   'Neural networks',
#   'Biological neural networks'],
#  'ieee_34782': ['Computational and artificial intelligence',
#   'Neural networks',
#   'Neural network compression'],
#  'ieee_19575': ['Computational and artificial intelligence',
#   'Computational intelligence',
#   'Fuzzy systems',
#   'Fuzzy control'],
#  'ieee_44157': ['Computational and artificial intelligence',
#   'Artificial intelligence',
#   'Retrieval augmented generation'],
#  'ieee_16665': ['Computational and artificial intelligence',
#   'Neural networks',
#   'Multi-layer neural network'],
#  'ieee_28519': ['Computational and artificial intelligence', 'Other'],
#  'ieee_44257': ['Computational and artificial intelligence', 'Other'],
#  'ieee_54323': ['Computational and artificial intelligence',
#   'Neural networks',
# ...
